# %% [markdown]
# # load libraries, set paths

# %%
import numpy as np
import pandas as pd
from compute_functions import *
from preprocess_functions import *
import os

base_dir = os.getcwd() # get dir of current file (this notebook)
# TODO: add dependency management

# %% [markdown]
# # optimal table computation

# %%
full_Q, optimal_Q = build_decision_tbl("rules/default")
optimal_Q
# Out:
# /Users/se/Projects/tSFP_influence_island/compute_functions.py:137: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   optimal_Q_table = full_Q_table.groupby(["trial", "score", "vs_left"]).apply(lambda x: x.loc[x["win_probability"].idxmax()])
# /Users/se/Projects/tSFP_influence_island/compute_functions.py:137: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   optimal_Q_table = full_Q_table.groupby(["trial", "score", "vs_left"]).apply(lambda x: x.loc[x["win_probability"].idxmax()])
# /Users/se/Projects/tSFP_influence_island/compute_functions.py:137: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   optimal_Q_table = full_Q_table.groupby(["trial", "score", "vs_left"]).apply(lambda x: x.loc[x["win_probability"].idxmax()])
#       trial  score  vs_left action  win_probability  round
# 0         1      0        0  small         0.018654      1
# 1         1      0        1  small         0.033981      1
# 2         1      0        2  small         0.060396      1
# 3         1      0        3  small         0.107539      1
# 4         1      1        0  small         0.018649      1
# ...     ...    ...      ...    ...              ...    ...
# 9691     10     99        3  small         0.050000      3
# 9692     10    100        0  small         0.000000      3
# 9693     10    100        1  small         0.000000      3
# 9694     10    100        2  small         0.000000      3
# 9695     10    100        3  small         0.000000      3
#
# [9696 rows x 6 columns]

# %% [markdown]
# # optimal table save/output

# %%
# add round labels 
policy_r1.insert(0, "round", 1)
policy_r2.insert(0, "round", 2)
policy_r3.insert(0, "round", 3)

# define save path 
save_optimal_tbl_path = os.path.join(base_dir, "data", "optimal_table.csv")

# concatenate dfs as one .csv, saved to data folder
optimal_tbl_df = pd.concat([policy_r1, policy_r2, policy_r3], ignore_index=True)
optimal_tbl_df.to_csv(save_optimal_tbl_path, index=False)
